# %%
import pandas as pd
import geopandas
import unicodedata

UF="PR"
df = pd.read_csv("cursos-prouni.csv")
file = open("geojs-41-mun.json")
geodata = geopandas.read_file(file)
# df=df.loc[df["uf_busca"]==UF]
df.rename(columns={'cidade_busca':'name'}, inplace=True)
c="name"

df[c]=df[c].str.lower().map(lambda x: unicodedata.normalize('NFKD', x)).str.encode('ascii', 'ignore')
geodata[c]=geodata[c].str.lower().map(lambda x: unicodedata.normalize('NFKD', x)).str.encode('ascii', 'ignore')

df3=pd.merge(df,geodata,on="name")
gdf3 = geopandas.GeoDataFrame(
    df3, geometry=df3["geometry"])
gdf3.plot()

# %%
import pandas as pd
import geopandas
import unicodedata

df = pd.read_csv("cursos-prouni.csv")
file = open("br-states.json")
geodata = geopandas.read_file(file)
df.rename(columns={'uf_busca':'id'}, inplace=True)
df=df.groupby("id").count()

df3=pd.merge(df,geodata,on="id")
gdf3 = geopandas.GeoDataFrame(
    df3, geometry=df3["geometry"])
gdf3.plot()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)

gdf3.plot(column="nota_integral_ampla", ax=ax, legend=True)

# %%
gdf3
# Out:
#     id   grau  turno  mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# 0   AC    203    203          203                   157                    55
# 1   AL    327    327          327                   274                   184
# 2   AM    429    429          429                   347                   208
# 3   AP    219    219          219                   174                   104
# 4   BA   2505   2505         2505                  1916                   792
# 5   CE    816    816          816                   604                   409
# 6   DF   1063   1063         1063                   908                   472
# 7   ES    825    825          825                   667                   401
# 8   GO   1278   1278         1278                  1007                   595
# 9   MA    679    679          679                   527                   247
# 10  MG   4175   4175         4175                  3295                  1939
# 11  MS    785    785          785                   590                   372
# 12  MT   1063   1063         1063                   803                   390
# 13  PA   1201   1201         1201                   852                   387
# 14  PB    596    596          596                   515                   352
# 15  PE   1148   1148         1148                   918                   651
# 16  PI    405    405          405                   348                   242
# 17  PR   3918   3918         3918                  2746                  2746
# 18  RJ   1442   1442         1442                  1221                   663
# 19  RN    342    342          342                   304                   202
# 20  RO    463    463          463                   385                   248
# 21  RR    111    111          111                    95                    36
# 22  RS   3060   3060         3060                  2448                  2448
# 23  SC   2195   2195         2195                  1600                  1600
# 24  SE    323    323          323                   296                   232
# 25  SP  11533  11533        11533                  9231                  9231
# 26  TO    343    343          343                   292                   198
#
#     bolsa_parcial_cotas  bolsa_parcial_ampla  curso_id  curso_busca  ...  \
# 0                   127                   85       203          203  ...
# 1                    91                   42       327          327  ...
# 2                    53                   76       429          429  ...
# 3                    73                   16       219          219  ...
# 4                   931                  608      2505         2505  ...
# 5                   200                  317       816          816  ...
# 6                   332                  331      1063         1063  ...
# 7                   306                  246       825          825  ...
# 8                   395                  303      1278         1278  ...
# 9                   254                  248       679          679  ...
# 10                 1068                  986      4175         4175  ...
# 11                  314                  131       785          785  ...
# 12                  388                  158      1063         1063  ...
# 13                  444                  140      1201         1201  ...
# 14                  117                  111       596          596  ...
# 15                  164                  270      1148         1148  ...
# 16                   64                  112       405          405  ...
# 17                  874                 2121      3918         3918  ...
# 18                  305                  195      1442         1442  ...
# 19                  100                   82       342          342  ...
# 20                  202                  184       463          463  ...
# 21                   27                    6       111          111  ...
# 22                   94                 1012      3060         3060  ...
# 23                   40                  868      2195         2195  ...
# 24                   78                   70       323          323  ...
# 25                 1719                 4287     11533        11533  ...
# 26                   68                   36       343          343  ...
#
#     universidade_nome  campus_nome  campus_id  nome_x  nota_integral_ampla  \
# 0                 203          203        203     203                  157
# 1                 327          327        327     327                  274
# 2                 429          429        429     429                  347
# 3                 219          219        219     219                  174
# 4                2505         2505       2505    2505                 1916
# 5                 816          816        816     816                  604
# 6                1063         1063       1063    1063                  908
# 7                 825          825        825     825                  667
# 8                1278         1278       1278    1278                 1007
# 9                 679          679        679     679                  527
# 10               4175         4175       4175    4175                 3295
# 11                785          785        785     785                  590
# 12               1063         1063       1063    1063                  803
# 13               1201         1201       1201    1201                  852
# 14                596          596        596     596                  515
# 15               1148         1148       1148    1148                  918
# 16                405          405        405     405                  348
# 17               3918         3918       3918    3918                 2746
# 18               1442         1442       1442    1442                 1221
# 19                342          342        342     342                  304
# 20                463          463        463     463                  385
# 21                111          111        111     111                   95
# 22               3060         3060       3060    3060                 2448
# 23               2195         2195       2195    2195                 1600
# 24                323          323        323     323                  296
# 25              11533        11533      11533   11533                 9231
# 26                343          343        343     343                  292
#
#     nota_integral_cotas  nota_parcial_ampla  nota_parcial_cotas  \
# 0                    53                 135                  77
# 1                   184                  92                  41
# 2                   197                 117                  12
# 3                    98                  78                  11
# 4                   749                1131                 408
# 5                   396                 376                 141
# 6                   465                 427                 236
# 7                   378                 372                 180
# 8                   585                 488                 210
# 9                   246                 387                 115
# 10                 1872                1631                 423
# 11                  371                 325                 120
# 12                  389                 399                 147
# 13                  385                 511                  73
# 14                  351                 175                  53
# 15                  644                 367                  67
# 16                  236                 123                  53
# 17                 1224                2121                 874
# 18                  646                 386                 114
# 19                  202                 108                  74
# 20                  229                 241                 145
# 21                   34                  27                   6
# 22                  573                1012                  94
# 23                  346                 868                  40
# 24                  232                  83                  65
# 25                 5542                4287                1719
# 26                  175                  83                  21
#
#                  nome_y                                           geometry
# 0                  Acre  POLYGON ((-73.80509 -7.10913, -70.32732 -8.138...
# 1               Alagoas  POLYGON ((-35.11884 -8.87971, -35.34991 -9.246...
# 2              Amazonas  POLYGON ((-63.39137 2.20006, -62.73341 1.84516...
# 3                 Amapá  POLYGON ((-50.13825 0.65178, -51.71656 -0.7288...
# 4                 Bahia  POLYGON ((-38.22455 -9.32040, -37.99348 -9.499...
# 5                 Ceará  POLYGON ((-37.30028 -4.81596, -37.63317 -4.948...
# 6      Distrito Federal  POLYGON ((-47.31061 -16.04782, -48.27796 -16.0...
# 7        Espírito Santo  POLYGON ((-40.92687 -21.30885, -41.71798 -21.1...
# 8                 Goiás  POLYGON ((-50.58081 -12.79526, -49.33147 -13.1...
# 9              Maranhão  POLYGON ((-48.54428 -5.16305, -47.54951 -4.546...
# 10         Minas Gerais  POLYGON ((-39.95952 -15.99712, -40.26500 -16.8...
# 11   Mato Grosso do Sul  POLYGON ((-53.08339 -17.99389, -52.83666 -18.6...
# 12          Mato Grosso  POLYGON ((-60.67338 -13.69615, -59.83919 -12.2...
# 13                 Pará  POLYGON ((-46.07302 -1.03690, -46.88372 -3.567...
# 14              Paraíba  POLYGON ((-34.97002 -6.48514, -34.81728 -7.545...
# 15           Pernambuco  POLYGON ((-34.81728 -7.54592, -35.11884 -8.879...
# 16                Piauí  POLYGON ((-41.81981 -2.72558, -41.32242 -2.912...
# 17               Paraná  POLYGON ((-53.09514 -22.58414, -49.76228 -23.0...
# 18       Rio de Janeiro  POLYGON ((-44.74145 -23.36023, -44.86286 -23.0...
# 19  Rio Grande do Norte  POLYGON ((-37.30028 -4.81596, -36.66974 -5.081...
# 20             Rondônia  POLYGON ((-66.80647 -9.81569, -66.30517 -9.421...
# 21              Roraima  POLYGON ((-58.87967 1.28357, -58.90317 0.27348...
# 22    Rio Grande do Sul  POLYGON ((-53.83534 -27.17048, -51.76748 -27.4...
# 23       Santa Catarina  POLYGON ((-53.63952 -26.26179, -51.37975 -26.6...
# 24              Sergipe  POLYGON ((-37.99348 -9.49980, -36.95563 -10.00...
# 25            São Paulo  POLYGON ((-44.74145 -23.36023, -45.42682 -23.6...
# 26            Tocantins  POLYGON ((-45.81454 -10.25249, -46.56649 -11.3...
#
# [27 rows x 22 columns]

# %%
import geopandas
import pandas as pd

filename = "countries.geojson"
file = open(filename)
df = geopandas.read_file(file)


df.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-fc74ad90c51d> in <module>
#       3
#       4 filename = "countries.geojson"
# ----> 5 file = open(filename)
#       6 df = geopandas.read_file(file)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'countries.geojson'

# %%
df.rename(columns={'sovereignt':'Country'}, inplace=True)
df.head()
# Out:
#     mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# id
# AC   570.743645              1.528662              1.236364
# AL   534.481284              2.547445              1.777174
# AM   576.651958              3.400576              2.000000
# AP   578.471918              3.114943              1.625000
# BA   639.848802              2.348121              1.902778
#
#     bolsa_parcial_cotas  bolsa_parcial_ampla      curso_id      campus_id  \
# id
# AC             2.338583             1.588235  2.828188e+13  483912.167488
# AL             1.791209             2.619048  4.374949e+13  706522.076453
# AM             2.037736            21.763158  3.276173e+13  601319.515152
# AP             1.643836             1.625000  3.422396e+13  692944.109589
# BA             2.701396            13.628289  4.907284e+13  720148.762874
#
#     nota_integral_ampla  nota_integral_cotas  nota_parcial_ampla  \
# id
# AC           592.320255           597.901887          567.295556
# AL           598.094599           587.339457          559.630435
# AM           580.413199           568.020102          526.945128
# AP           583.807126           571.523469          527.139744
# BA           588.942140           580.011162          524.612396
#
#     nota_parcial_cotas
# id
# AC          560.335584
# AL          545.240000
# AM          537.891667
# AP          528.025455
# BA          506.756225

# %%
filename2 = "HDI.csv"
file2 = open(filename2)
df2 = pd.read_csv(file2)
df2.head(8)
df3 = pd.merge(df,df2,on="Country")
df3.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-c8fca9c5d034> in <module>
#       1 filename2 = "HDI.csv"
# ----> 2 file2 = open(filename2)
#       3 df2 = pd.read_csv(file2)
#       4 df2.head(8)
#       5 df3 = pd.merge(df,df2,on="Country")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'HDI.csv'

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)

df = df[df["ESTUF"]!="SC"]
df.plot(column="ALCANCE", ax=ax, legend=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ESTUF'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-556ba49a9a31> in <module>
#       3 fig, ax = plt.subplots(1, 1)
#       4
# ----> 5 df = df[df["ESTUF"]!="SC"]
#       6 df.plot(column="ALCANCE", ax=ax, legend=True)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ESTUF'
