# %%
import geopandas

filename = "Planos_Estaduais_de_Recursos_Hidricos.geojson"
file = open(filename)
df = geopandas.read_file(file)

df.plot()

# %%
df.head()
# Out:
#   ESTUF ESTREGIAO          STATUS  ANO_CONCLU ALCANCE  OBJECTID  \
# 0    RS       Sul   Em elaboração           2               321
# 1    SC       Sul  Em contratação           1               322
# 2    PR       Sul       Elaborado        2010    2014       323
# 3    SP   Sudeste       Elaborado        2012    2015       324
# 4    RJ   Sudeste       Elaborado        2014    2030       325
#
#                                             geometry
# 0  POLYGON ((-50.17258 -29.24914, -50.17447 -29.2...
# 1  MULTIPOLYGON (((-48.54405 -26.16947, -48.54859...
# 2  POLYGON ((-48.18659 -25.12484, -48.18667 -25.1...
# 3  MULTIPOLYGON (((-45.76810 -22.82957, -45.76784...
# 4  POLYGON ((-44.31743 -22.84054, -44.31786 -22.8...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)

df = df[df["ESTUF"]!="SC"]
df.plot(column="ALCANCE", ax=ax, legend=True)
